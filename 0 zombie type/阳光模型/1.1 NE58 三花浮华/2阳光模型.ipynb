# %%
import pandas as pd
import statsmodels.api as sm
from matplotlib import pyplot as plt  

# df = pd.read_excel('2阳光信息.xlsx',usecols=['Y','红','气','橄','舞','篮','撑','白','权重和'])
df = pd.read_excel('2阳光信息.xlsx',usecols=['Y','红','气','橄','舞','篮','白','权重和'])
df['权重和']=df['权重和']/10000

X = df.iloc[:,1:]
y = -df['Y']

# print(X)
# print(y)
# Out:
# 0      245
# 1      665
# 2      125
# 3      980
# 4      -20
# 5       15
# 6      750
# 7      265
# 8      390
# 9      155
# 10    -155
# 11    -695
# 12   -1250
# 13    -230
# 14      50
# 15     205
# 16     -10
# 17     340
# 18     155
# 19     -90
# 20     -35
# 21     555
# 22    -140
# 23    -595
# 24     280
# Name: Y, dtype: int64

# %%
X_sm = sm.add_constant(X)
model_sm = sm.OLS(y, X_sm).fit()
print(model_sm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.811
# Model:                            OLS   Adj. R-squared:                  0.733
# Method:                 Least Squares   F-statistic:                     10.41
# Date:                Tue, 29 Apr 2025   Prob (F-statistic):           4.52e-05
# Time:                        10:27:26   Log-Likelihood:                -167.75
# No. Observations:                  25   AIC:                             351.5
# Df Residuals:                      17   BIC:                             361.3
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -816.7716    504.754     -1.618      0.124   -1881.709     248.165
# 红           1077.9236    209.331      5.149      0.000     636.274    1519.573
# 气            561.8667    126.199      4.452      0.000     295.611     828.123
# 橄            455.7580    120.064      3.796      0.001     202.446     709.070
# 舞            116.0912    140.999      0.823      0.422    -181.391     413.573
# 篮             75.9014    106.063      0.716      0.484    -147.872     299.674
# 白            138.0911    112.863      1.224      0.238    -100.030     376.212
# 权重和         -554.1744    292.443     -1.895      0.075   -1171.176      62.827
# ==============================================================================
# Omnibus:                        1.564   Durbin-Watson:                   2.307
# Prob(Omnibus):                  0.457   Jarque-Bera (JB):                0.703
# Skew:                           0.396   Prob(JB):                        0.704
# Kurtosis:                       3.216   Cond. No.                         26.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
