# %%
import pandas as pd
import statsmodels.api as sm
from matplotlib import pyplot as plt  

# df = pd.read_excel('2阳光信息.xlsx',usecols=['Y','红','气','橄','丑','篮','舞','撑','白','权重和'])
# df['权重和']=df['权重和']/10000
df = pd.read_excel('2阳光信息.xlsx',usecols=['Y','红','气','橄','舞','白','权重和'])
df['权重和']=df['权重和']/10000

X = df.iloc[:,1:]
y = -df['Y']

# print(X)
# print(y)

# %%
X_sm = sm.add_constant(X)
model_sm = sm.OLS(y, X_sm).fit()
print(model_sm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.817
# Model:                            OLS   Adj. R-squared:                  0.792
# Method:                 Least Squares   F-statistic:                     32.02
# Date:                Sat, 12 Apr 2025   Prob (F-statistic):           2.47e-14
# Time:                        08:42:10   Log-Likelihood:                -321.39
# No. Observations:                  50   AIC:                             656.8
# Df Residuals:                      43   BIC:                             670.2
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -423.2515    212.870     -1.988      0.053    -852.546       6.043
# 红            143.5044     54.229      2.646      0.011      34.140     252.868
# 气            762.7900     61.089     12.487      0.000     639.593     885.987
# 橄            175.4549     46.894      3.741      0.001      80.883     270.026
# 舞            100.2125     46.724      2.145      0.038       5.985     194.440
# 白            -99.8043     46.595     -2.142      0.038    -193.772      -5.836
# 权重和         -275.3930    135.417     -2.034      0.048    -548.487      -2.299
# ==============================================================================
# Omnibus:                        0.779   Durbin-Watson:                   2.012
# Prob(Omnibus):                  0.677   Jarque-Bera (JB):                0.532
# Skew:                           0.252   Prob(JB):                        0.767
# Kurtosis:                       2.967   Cond. No.                         24.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
