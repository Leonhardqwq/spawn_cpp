# %%
import pandas as pd
import statsmodels.api as sm
from matplotlib import pyplot as plt  

# df = pd.read_excel('2.1阳光信息.xlsx',usecols=['Y','红','气','橄','舞','篮','撑','白','权重和'])
df = pd.read_excel('2.1阳光信息.xlsx',usecols=['Y','气','橄','舞','权重和'])
df['权重和']=df['权重和']/10000

X = df.iloc[:,1:]
y = -df['Y']

# print(X)
# print(y)

# %%
X_sm = X
# X_sm = sm.add_constant(X)
model_sm = sm.OLS(y, X_sm).fit()
print(model_sm.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      Y   R-squared (uncentered):                   0.810
# Model:                            OLS   Adj. R-squared (uncentered):              0.683
# Method:                 Least Squares   F-statistic:                              6.388
# Date:                Tue, 29 Apr 2025   Prob (F-statistic):                      0.0236
# Time:                        19:55:38   Log-Likelihood:                         -65.856
# No. Observations:                  10   AIC:                                      139.7
# Df Residuals:                       6   BIC:                                      140.9
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 气            591.2405    157.815      3.746      0.010     205.080     977.401
# 橄            394.9816    159.945      2.469      0.048       3.611     786.352
# 舞            145.4933    153.569      0.947      0.380    -230.277     521.264
# 权重和         -563.8768    127.600     -4.419      0.004    -876.102    -251.651
# ==============================================================================
# Omnibus:                        0.154   Durbin-Watson:                   1.745
# Prob(Omnibus):                  0.926   Jarque-Bera (JB):                0.288
# Skew:                          -0.218   Prob(JB):                        0.866
# Kurtosis:                       2.292   Cond. No.                         5.02
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# c:\MyFile\anaconda3\Lib\site-packages\scipy\stats\_axis_nan_policy.py:531: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   res = hypotest_fun_out(*samples, **kwds)
