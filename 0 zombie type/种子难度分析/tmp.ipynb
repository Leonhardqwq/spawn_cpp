# %%
f'{66447:b}'
# Out:
# '10000001110001111'

# %%
import numpy as np
import pandas as pd
from scipy.stats import norm,chi2,t,binom
from math import comb
import matplotlib.pyplot as plt
import random
import math

# %%
# 炽热PE无神
# 2222-2322 20/50
seed = f'{831686198-1-13-1112*0x65:X}'
info = [847574311,1228989705,4294967964]
print(f'{seed}:[{info[0]/info[2]},{info[1]/info[2]}]')
# Out:
# 3190CF70:[0.19734124168196007,0.2861464195545278]

# %%
# 老手两仪
# 2222-2322 21/50
# 2222-2622 91/200

seed = f'{1953467352-1-13-(1116)*0x65:X}'
info = [1228989705,1674897662,4294967964]
print(f'{seed}:[{info[0]/info[2]},{info[1]/info[2]}]')
info = [2273375034,2513917422,4294969764]
print(f'{seed}:[{info[0]/info[2]},{info[1]/info[2]}]')
# Out:
# 746DD37E:[0.2861464195545278,0.38996744004584616]
# 746DD37E:[0.5293110682769407,0.5853166751187402]

# %%
# 煎饺
# 9998-10004 

seed = f'{1018671331-1-13-(4999)*0x65:X}'
info = [1228989705,1674897662,4294967964]
print(f'{seed}:[{info[0]/info[2]},{info[1]/info[2]}]')
# Out:
# 3CAFFC92:[0.2861464195545278,0.38996744004584616]

# %%
# 猫 N6E单花
# 11+24=35

info = [4156967126,4245018703,4294967652]
print(f':[{info[0]/info[2]},{info[1]/info[2]}]')
# Out:
# :[0.9678692513700916,0.9883703550184503]
